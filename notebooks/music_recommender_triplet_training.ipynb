# %% [markdown]
# <a href="https://colab.research.google.com/github/niczos/music-recommender-system/blob/main/notebooks/music_recommender_triplet_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main binary classifier training notebook

# %%
# install package with the project
# !pip install git+https://github.com/niczos/music-recommender-system.git >> log.txt
# Out:
#   Running command git clone --filter=blob:none --quiet https://github.com/niczos/music-recommender-system.git /tmp/pip-req-build-0t9503yj

# %%
# %load_ext autoreload
# %autoreload 2
import scripts

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Modeling

# %%
import os
PROJECT_PATH = "/content/drive/MyDrive/Music_recommender/"
DATA_PATH = os.path.join(PROJECT_PATH, "data_small")

# %%
import yaml
# Read YAML file
with open(os.path.join(PROJECT_PATH,"colab_train_config.yaml"), 'r') as stream:
    config = yaml.safe_load(stream)

# %%
config
# Out:
# {'annotations_file': '/content/drive/MyDrive/Music_recommender/metadata_small.csv',
#  'val_annotations_file': '/content/drive/MyDrive/Music_recommender/val_metadata_small.csv',
#  'music_dir': '/content/drive/MyDrive/Music_recommender/sample_data_small',
#  'music_parts': ['Chorus', 'Verse'],
#  'temp_dir': '/content/drive/MyDrive/Music_recommender/temp',
#  'models_path': '/content/drive/MyDrive/Music_recommender/models',
#  'batch_size': 4,
#  'norm': 'cosine',
#  'num_epochs': 2,
#  'lr': 0.002,
#  'triplet_loss_margin': 1.0,
#  'output_dir': '/content/drive/MyDrive/Music_recommender/results'}

# %%
from music_recommender.scripts.triplet_training import main
main(config)
# /content/drive/MyDrive/Music_recommender/models/triplet_ssrl_learning_XXXXXXX/model_epoch_7.pth
# main(config,resume_epoch=7, checkpoint_path=/content/drive/MyDrive/Music_recommender/models/triplet_ssrl_learning_XXXXXXX/)
# Out:
# Starting training with 2 epochs on cuda.
#
# --- Epoch 1/2 ---
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
#   Batch [1/1] Loss: 0.954155, Time: 1.54s
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# Epoch [1/2] Average Training Loss: 0.954155, Epoch Time: 52.61s
# Epoch [1/2] Validation Loss: 0.000000
#
# --- Epoch 2/2 ---
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
#   Batch [1/1] Loss: 0.000000, Time: 0.34s
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# /usr/local/lib/python3.11/dist-packages/music_recommender/src/audio_processing.py:18: UserWarning: PySoundFile failed. Trying audioread instead.
#   self.y, self.sample_rate = librosa.load(path=self.filepath)
# Epoch [2/2] Average Training Loss: 0.000000, Epoch Time: 29.67s
# Epoch [2/2] Validation Loss: 1.243602
#
# Training complete.
# Saving model to /content/drive/MyDrive/Music_recommender/results/model_weights.pth
